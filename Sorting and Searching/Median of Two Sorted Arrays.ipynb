# %%
nums1 = [1, 2, 3, 4, 5, 6, 7, 8]
nums2 = [1, 2, 3, 4, 5]

# %%
len1 = len(nums1)
len2 = len(nums2)

# %%
len1, len2
# Out:
# (8, 5)

# %%
p1 = len1 // 2
p2 = len2 // 2

# %%
p1, p2
# Out:
# (4, 2)

# %%
l1, r1 = 0, len1 - 1
l2, r2 = 0, len2 - 1

# %%
l1, r1
# Out:
# (0, 7)

# %%
l2, r2
# Out:
# (0, 4)

# %%
assert len1 == len2, 'mst'

# %%
def partition(pts1, pts2):
  pts1 = l1, r1
  pts2 = l2, r2
  
  if r1 - l1 + 1 % 2 == 0:

# %%
side1 = 'left'
side2 = 'right'

while r1 - l1 > 1 and r2 - l2 > 1:

  if r1 - l1 + 1 % 2 == 0 and r2 - l2 + 1 % 2 == 0:
    if nums1[(r1 - l1) // 2] > nums2[(r2 - l2) // 2 + 1]:
      r1 =
