# %%
def FindPeakStep(nums, left, right):
  n = len(nums)

  mid = int(left + (right - left) / 2)
  if (mid == 0 or nums[mid - 1] < nums[mid]) and (mid == n - 1 or nums[mid] > nums[mid + 1]):
    return mid
  
  elif mid > 0 and nums[mid - 1] > nums[mid]:
    return FindPeakStep(nums, left, mid - 1)
  else: 
    return FindPeakStep(nums, mid + 1, right)

# %%
def FindPeak(nums):
  return FindPeakStep(nums, 0, len(nums) - 1)

# %%
nums = [1,2,3,4,1]

# %%
FindPeak(nums)
# Out:
# 3

# %%
def FindPeakStep(nums, left, right):
  n = len(nums)

  mid = int(left + (right - left) / 2)
  if (mid == 0 or nums[mid - 1] < nums[mid]) and (mid == n - 1 or nums[mid] > nums[mid + 1]):
    return mid
  
  elif mid > 0 and nums[mid - 1] > nums[mid]:
    return FindPeakStep(nums, left, mid - 1)
  else: 
    return FindPeakStep(nums, mid + 1, right)

def FindPeak(nums):
  return FindPeakStep(nums, 0, len(nums) - 1)

class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        return FindPeak(nums)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
