# %%
root = [3,5,1,6,2,0,8,null,null,7,4]
p = 5
q = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-31bafb5a31c9> in <module>()
# ----> 1 root = [3,5,1,6,2,0,8,null,null,7,4]
#       2 p = 5
#       3 q = 1
#
# NameError: name 'null' is not defined
