# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nums[1::2]
# Out:
# [1, 4, 6]

# %%
nums = [1,5,1,1,6,4]
def WiggleSort(nums):
  nums = sorted(nums)
  m = (len(nums) / 2) + 1

# %%
nums = sorted(nums)
m = (len(nums) / 2) + 1

# %%
nums
# Out:
# [1, 1, 1, 4, 5, 6]

# %%
m
# Out:
# 4.0

# %%
nums[::2] > m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-315d7eec2406> in <module>()
# ----> 1 nums[::2] > m
#
# TypeError: '>' not supported between instances of 'list' and 'float'
