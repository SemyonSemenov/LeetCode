# %%
def position(letter):
    return ord(letter) - 97 + 32 + 1

def create(k):
  if k == 0:
    return 1
  else:
    sum = 1
    for i in range(k):
      sum *= 26
    return int(26 * (sum - 1) / 25)

def add(k):
  sum = 1
  for i in range(k):
    sum *= 26

  return sum

# %%
def ESCN(columnTitle):
  lenght = len(columnTitle)

  pos = create(lenght - 1)

  for i in range(lenght):
    pos += add(lenght - i - 1) * (position(columnTitle[i]) - 1)

  if lenght > 1:
    pos += 1

  return pos

# %%
columnTitle = "FXSHRXW"
ESCN(columnTitle)
# Out:
# 2147483647

# %%
def position(letter):
    return ord(letter) - 97 + 32 + 1

def create(k):
  if k == 0:
    return 1
  else:
    sum = 1
    for i in range(k):
      sum *= 26
    return int(26 * (sum - 1) / 25)

def add(k):
  sum = 1
  for i in range(k):
    sum *= 26

  return sum

def ESCN(columnTitle):
  lenght = len(columnTitle)

  pos = create(lenght - 1)

  for i in range(lenght):
    pos += add(lenght - i - 1) * (position(columnTitle[i]) - 1)

  if lenght > 1:
    pos += 1

  return pos

class Solution:
    def titleToNumber(self, columnTitle: str) -> int:
        return ESCN(columnTitle)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
