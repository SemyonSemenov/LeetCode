# %%
n = 29

# %%
p = 5
counter = 0


while True:
  if p <= n:
    counter += n // p
    p *= 5
  else:
    break

counter
# Out:
# 6

# %%
class Solution:
    def trailingZeroes(self, n: int) -> int:
        p = 5
        counter = 0
        
        while True:
            if p <= n:
                counter += n // p
                p *= 5
            else:
                break

        return counter

# %% [markdown]
# ![image.png](data:image/png;base64,...)
